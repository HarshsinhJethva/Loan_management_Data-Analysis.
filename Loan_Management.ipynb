# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine
import cryptography

# %%
# attration
attration = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Attrition_By_Branch_Data.csv')

# collection
collection_May = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Collection_May_2024.csv')
collection_Jun = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Collection_Jun_2024.csv')
collection_Jul = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Collection_Jul_2024.csv')
collection_Aug = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Collection_Aug_2024.csv')

# portfolio_Report
portfolio_May = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Portfolio_Report_May_2024.csv')
portfolio_Jun = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Portfolio_Report_Jun_2024.csv')
portfolio_Jul = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Portfolio_Report_Jul_2024.csv')
portfolio_Aug = pd.read_csv(r'/Users/harshsinhjethva/DataScience Intership/Loan_Management_Files/Portfolio_Report_Aug_2024.csv')

# %%
collection_concat = pd.concat([collection_May,collection_Jun,collection_Jul,collection_Aug], ignore_index=True)
portfolio_concat = pd.concat([portfolio_May,portfolio_Jun,portfolio_Jul,portfolio_Aug], ignore_index=True)

# %%
attration.head()
# Out:
#        Month         Branch name & code  Opening Balance  New Joinee  Exit  \
# 0  July 2024        Hisar - HARHISR2021             18.0         4.0   9.0
# 1  July 2024  Hoshangabad - MDPHSBD2021             15.0         NaN   6.0
# 2  July 2024       Buguda - ODSBGDA2023              6.0         2.0   3.0
# 3  July 2024  Chhendipada - ODSCNDP2023              9.0         2.0   4.0
# 4  July 2024     Salumber - RAJSLMB2019              5.0         1.0   2.0
#
#    Transfer / Promoted To  Transfer  / Promoted From  Closing Balance
# 0                     1.0                        2.0             14.0
# 1                     NaN                        1.0             10.0
# 2                     NaN                        1.0              6.0
# 3                     1.0                        NaN              6.0
# 4                     NaN                        NaN              4.0

# %%
attration['Month'] = pd.to_datetime(attration['Month'], errors='coerce')
attration ['Month'] = attration['Month'].dt.strftime('%d-%m-%Y')
attration
# Out:
# /var/folders/fc/sk3p9t7n0bqdb9bf4w53qjb00000gn/T/ipykernel_6605/3974873272.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   attration['Month'] = pd.to_datetime(attration['Month'], errors='coerce')
#            Month         Branch name & code  Opening Balance  New Joinee  \
# 0     01-07-2024        Hisar - HARHISR2021             18.0         4.0
# 1     01-07-2024  Hoshangabad - MDPHSBD2021             15.0         NaN
# 2     01-07-2024       Buguda - ODSBGDA2023              6.0         2.0
# 3     01-07-2024  Chhendipada - ODSCNDP2023              9.0         2.0
# 4     01-07-2024     Salumber - RAJSLMB2019              5.0         1.0
# ...          ...                        ...              ...         ...
# 1012  01-08-2024       Thasra - GUJTSRA2019             20.0         2.0
# ...

# %%
attration['Branch Name'] = attration['Branch name & code'].str.split(' - ').str[0]
attration['Branch Code'] = attration['Branch name & code'].str.split(' - ').str[1]
attration.head(5)
# Out:
#         Month         Branch name & code  Opening Balance  New Joinee  Exit  \
# 0  01-07-2024        Hisar - HARHISR2021             18.0         4.0   9.0
# 1  01-07-2024  Hoshangabad - MDPHSBD2021             15.0         NaN   6.0
# 2  01-07-2024       Buguda - ODSBGDA2023              6.0         2.0   3.0
# 3  01-07-2024  Chhendipada - ODSCNDP2023              9.0         2.0   4.0
# 4  01-07-2024     Salumber - RAJSLMB2019              5.0         1.0   2.0
#
#    Transfer / Promoted To  Transfer  / Promoted From  Closing Balance  \
# 0                     1.0                        2.0             14.0
# 1                     NaN                        1.0             10.0
# 2                     NaN                        1.0              6.0
# 3                     1.0                        NaN              6.0
# 4                     NaN                        NaN              4.0
#
#    Branch Name  Branch Code
# 0        Hisar  HARHISR2021
# 1  Hoshangabad  MDPHSBD2021
# ...

# %%
# attration.isnull().sum()
attrition = attration
missing_pct_attration = attrition.isnull().mean().multiply(100).round(1)
missing_pct_attration
# Out:
# Month                         0.0
# Branch name & code            0.0
# Opening Balance               0.4
# New Joinee                   37.6
# Exit                         33.5
# Transfer / Promoted To       62.8
# Transfer  / Promoted From    60.3
# Closing Balance               0.2
# Branch Name                   0.0
# Branch Code                   0.0
# dtype: float64

# %%
# clean_Attration = ['Opening Balance','New Joinee','Transfer / Promoted To','Exit','Transfer  / Promoted From','Closing Balance']
# attration[clean_Attration] = attrition[clean_Attration].fillna(0, inplace=True)
attrition.fillna({
    'Opening Balance': 0,
    'New Joinee': 0,
    'Transfer / Promoted To': 0,
    'Exit': 0,
    'Transfer  / Promoted From': 0,
    'Closing Balance': 0
}, inplace=True)

# %%
attrition = attration
missing_pct_attration = attrition.isnull().mean().multiply(100).round(1)
missing_pct_attration
# Out:
# Month                        0.0
# Branch name & code           0.0
# Opening Balance              0.0
# New Joinee                   0.0
# Exit                         0.0
# Transfer / Promoted To       0.0
# Transfer  / Promoted From    0.0
# Closing Balance              0.0
# Branch Name                  0.0
# Branch Code                  0.0
# dtype: float64

# %%
# attration[clean_Attration] = attrition[clean_Attration].astype(int)
attrition.head()
# Out:
#         Month         Branch name & code  Opening Balance  New Joinee  Exit  \
# 0  01-07-2024        Hisar - HARHISR2021             18.0         4.0   9.0
# 1  01-07-2024  Hoshangabad - MDPHSBD2021             15.0         0.0   6.0
# 2  01-07-2024       Buguda - ODSBGDA2023              6.0         2.0   3.0
# 3  01-07-2024  Chhendipada - ODSCNDP2023              9.0         2.0   4.0
# 4  01-07-2024     Salumber - RAJSLMB2019              5.0         1.0   2.0
#
#    Transfer / Promoted To  Transfer  / Promoted From  Closing Balance  \
# 0                     1.0                        2.0             14.0
# 1                     0.0                        1.0             10.0
# 2                     0.0                        1.0              6.0
# 3                     1.0                        0.0              6.0
# 4                     0.0                        0.0              4.0
#
#    Branch Name  Branch Code
# 0        Hisar  HARHISR2021
# 1  Hoshangabad  MDPHSBD2021
# ...

# %%
attrition = attration
# missing_pct = attrition.isnull().mean().multiply(100).round(1)
missing_pct_attration = (attration.isnull().sum()/attration.shape[0])*100
missing_pct_attration
# Out:
# Month                        0.0
# Branch name & code           0.0
# Opening Balance              0.0
# New Joinee                   0.0
# Exit                         0.0
# Transfer / Promoted To       0.0
# Transfer  / Promoted From    0.0
# Closing Balance              0.0
# Branch Name                  0.0
# Branch Code                  0.0
# dtype: float64

# %%
portfolio_concat.head(20)
# Out:
#     ClientId  AccountId  LoanAmt                DisbursedDate  InterestRate  \
# 0      27585     132014  10267.0  2015-03-02 00:00:00.0000000           0.0
# 1      27585     132015  13987.0  2015-03-02 00:00:00.0000000           0.0
# 2      34840     132688  13987.0  2015-03-03 00:00:00.0000000           0.0
# 3      58874     162977  24290.0  2015-05-11 00:00:00.0000000           0.0
# 4      24304     245698    655.0  2015-11-17 00:00:00.0000000           0.0
# 5      80085     247183  22445.0  2015-10-16 00:00:00.0000000           0.0
# 6      23087     248380   3213.0  2015-09-30 00:00:00.0000000           0.0
# 7      13220     248645  17075.0  2015-11-11 00:00:00.0000000           0.0
# 8      13220     248647  14340.0  2015-11-11 00:00:00.0000000           0.0
# 9      52878     251617   9153.0  2015-11-11 00:00:00.0000000           0.0
# 10     52878     251618  18450.0  2015-11-11 00:00:00.0000000           0.0
# ...

# %%
portfolio_concat.shape
# Out:
# (2191613, 19)

# %%
missing_pct_portfolio = (portfolio_concat.isnull().sum()/portfolio_concat.shape[0])*100
missing_pct_portfolio
# Out:
# ClientId                  0.000000
# AccountId                 0.000000
# LoanAmt                   0.000000
# DisbursedDate             0.000000
# InterestRate              0.000000
# Instalment Amount         0.081036
# No of Instalment          0.000000
# Instalment remaining      0.000000
# PrincipalBalance          0.000000
# InterestBalance           0.000000
# Principal Overdue        93.389618
# Interest Overdue         93.389618
# last repayment date       6.319136
# report_generated_date     0.000000
# DPD                      93.389618
# BranchName               24.657957
# Product_name             24.657957
# Loan_counter_group       24.657957
# CenterName               74.838760
# dtype: float64

# %%
portfolio_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191613 entries, 0 to 2191612
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ClientId               int64
#  1   AccountId              int64
#  2   LoanAmt                float64
#  3   DisbursedDate          object
#  4   InterestRate           float64
#  5   Instalment Amount      float64
#  6   No of Instalment       int64
#  7   Instalment remaining   int64
#  8   PrincipalBalance       float64
#  9   InterestBalance        float64
#  10  Principal Overdue      float64
#  11  Interest Overdue       float64
#  12  last repayment date    object
#  13  report_generated_date  object
#  14  DPD                    float64
#  15  BranchName             object
#  16  Product_name           object
#  17  Loan_counter_group     object
#  18  CenterName             object
# dtypes: float64(8), int64(4), object(7)
# memory usage: 317.7+ MB

# %%
missing_pct_portfolio = (portfolio_concat.isnull().sum()/portfolio_concat.shape[0])*100
missing_pct_portfolio
# Out:
# ClientId                  0.000000
# AccountId                 0.000000
# LoanAmt                   0.000000
# DisbursedDate             0.000000
# InterestRate              0.000000
# Instalment Amount         0.081036
# No of Instalment          0.000000
# Instalment remaining      0.000000
# PrincipalBalance          0.000000
# InterestBalance           0.000000
# Principal Overdue        93.389618
# Interest Overdue         93.389618
# last repayment date       6.319136
# report_generated_date     0.000000
# DPD                      93.389618
# BranchName               24.657957
# Product_name             24.657957
# Loan_counter_group       24.657957
# CenterName               74.838760
# dtype: float64

# %%
portfolio_concat.fillna({
    'Instalment Amount': 0,
    'Principal Overdue': 0,
    'Interest Overdue': 0,
    'DPD': 0,
    'BranchName': 'Unknown',
    'Product_name': 'Unknown',
    'CenterName': 'Unknown',
    'Loan_counter_group': 'Unknown',
    'last repayment date': portfolio_concat['DisbursedDate'],
    'DisbursedDate': 'NaT'
}, inplace=True)

# %%
date_cols = ["DisbursedDate", "last repayment date", "report_generated_date"]
portfolio_concat[date_cols] = portfolio_concat[date_cols].apply(pd.to_datetime, errors='coerce',)
portfolio_concat[date_cols] = portfolio_concat[date_cols].apply(
    lambda col: col.dt.strftime('%d-%m-%Y').fillna('Not Available')
)
portfolio_concat.head(10)
# Out:
#    ClientId  AccountId  LoanAmt DisbursedDate  InterestRate  \
# 0     27585     132014  10267.0    02-03-2015           0.0
# 1     27585     132015  13987.0    02-03-2015           0.0
# 2     34840     132688  13987.0    03-03-2015           0.0
# 3     58874     162977  24290.0    11-05-2015           0.0
# 4     24304     245698    655.0    17-11-2015           0.0
# 5     80085     247183  22445.0    16-10-2015           0.0
# 6     23087     248380   3213.0    30-09-2015           0.0
# 7     13220     248645  17075.0    11-11-2015           0.0
# 8     13220     248647  14340.0    11-11-2015           0.0
# 9     52878     251617   9153.0    11-11-2015           0.0
#
#    Instalment Amount  No of Instalment  Instalment remaining  \
# 0                0.0               150                   125
# 1                0.0               150                   125
# 2                0.0               150                   125
# ...

# %%
missing_pct_portfolio = (portfolio_concat.isnull().sum()/portfolio_concat.shape[0])*100
missing_pct_portfolio
# Out:
# ClientId                 0.0
# AccountId                0.0
# LoanAmt                  0.0
# DisbursedDate            0.0
# InterestRate             0.0
# Instalment Amount        0.0
# No of Instalment         0.0
# Instalment remaining     0.0
# PrincipalBalance         0.0
# InterestBalance          0.0
# Principal Overdue        0.0
# Interest Overdue         0.0
# last repayment date      0.0
# report_generated_date    0.0
# DPD                      0.0
# BranchName               0.0
# Product_name             0.0
# Loan_counter_group       0.0
# CenterName               0.0
# dtype: float64

# %%
null_pct_portfolio = (collection_concat.isnull().sum() / collection_concat.shape[0]) * 100
null_pct_portfolio
# Out:
# State                              0.0
# District                           0.0
# Branch                             0.0
# Loan ID                            0.0
# Client ID                          0.0
# Loan Name                          0.0
# Actual Demand For The Month        0.0
# Total OD Amount Of Last Month      0.0
# OD Demand                          0.0
# Overall Demand For The Month       0.0
# Overall Collection                 0.0
# Regular Collection                 0.0
# OD Collection                      0.0
# Advanced Collection                0.0
# Pre_Payment                        0.0
# Loan Status                        0.0
# Advance + Pre Pay Coll.            0.0
# Loan Closed Month                100.0
# Due_Till_LM                      100.0
# Coll_Till_LM                     100.0
# Advance_Coll_LM                    0.0
# reportgenerateddate                0.0
# dtype: float64

# %%
collection_concat.drop(
    columns=['Loan Closed Month', 'Due_Till_LM', 'Coll_Till_LM'],
    inplace=True
)

# %%
collection_concat.head(10)
# Out:
#   State       District         Branch  Loan ID  Client ID  \
# 0    UP     Saharanpur          Nagal  3550131    4437687
# 1    HR  CHARKHI DADRI  CHARKHI DADRI  3538159    4402653
# 2   GUJ          Anand         Petlad  3534716    3475223
# 3   GUJ          Kutch          Anjar  3534615     364905
# 4   GUJ          Anand          Anand  3533006    3665492
# 5   GUJ      Ahmedabad   Ellishbridge  3530908    3642029
# 6   GUJ      Ahmedabad         Dholka  3530612    1310635
# 7    HR        Sonipat        Sonipat  3528794    2398312
# 8   GUJ          Dahod        Sanjeli  3528777     538283
# 9   RAJ           Pali           Pali  3528750     577824
#
#                      Loan Name  Actual Demand For The Month  \
# 0  Monthly Two Year Loan_50000                            0
# 1  Monthly Two Year Loan_60000                            0
# 2         Insurance Claim Loan                            0
# 3         Insurance Claim Loan                            0
# ...

# %%
coll_portfolio = pd.merge(collection_concat, portfolio_concat, how='left', left_on='Client ID', right_on='ClientId')

# %%
final_Att_Coll_Port = pd.merge(coll_portfolio, attrition, how='left', left_on='Branch', right_on='Branch Name')

# %%
final_Att_Coll_Port.shape
# Out:
# (28120387, 48)

# %%
whole_pct = (final_Att_Coll_Port.isnull().sum()/final_Att_Coll_Port.shape[0])*100
whole_pct
# Out:
# State                            0.000000
# District                         0.000000
# Branch                           0.000000
# Loan ID                          0.000000
# Client ID                        0.000000
# Loan Name                        0.000000
# Actual Demand For The Month      0.000000
# Total OD Amount Of Last Month    0.000000
# OD Demand                        0.000000
# Overall Demand For The Month     0.000000
# Overall Collection               0.000000
# Regular Collection               0.000000
# OD Collection                    0.000000
# Advanced Collection              0.000000
# Pre_Payment                      0.000000
# Loan Status                      0.000000
# Advance + Pre Pay Coll.          0.000000
# Advance_Coll_LM                  0.000000
# reportgenerateddate              0.000000
# ClientId                         0.045999
# AccountId                        0.045999
# LoanAmt                          0.045999
# ...

# %%
conn_sql = mysql.connector.connect(
    host ='localhost',
    user ='root',
    password = 'Hayosha@24',
    database = 'loan_managemnet'
)
cursor = conn_sql.cursor()

# %%
engine = create_engine("mysql+mysqlconnector://root:Hayosha%4024@localhost:3306/loan_managemnet")

# %%
collection_concat.to_sql(
    name='collection_data',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=1000,
    method='multi'
)
# Out:
# 2104575

# %%
portfolio_concat.to_sql(name='portfolio_data', con=engine, if_exists='replace', index=False, chunksize=1000,method='multi')
# Out:
# 2191613

# %%
attration.to_sql(name='attrition_data', con=engine, if_exists='replace', index=False)
# Out:
# 1017

# %%
attration.to_csv('attration_clean.csv', index=False)

# %%
portfolio_concat.to_csv('portfolio_concat_clean.csv', index=False)

# %%
collection_concat.to_csv('collection_concat_clean.csv', index=False)
